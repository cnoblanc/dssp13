# %%
import numpy as np
import pandas as pd

base_path="/Users/christophenoblanc/Documents/ProjetsPython/DSSP_Projet_DVF/data_dvf/"

df = pd.read_pickle(base_path+'DataFrame_2018')
pd.set_option('display.max_columns', 500)

# %%
# Quick Graphs to see some data
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')

# %%
df.boxplot(column='valeur_fonciere', by='type_local', ax=None, fontsize=None, rot=0, figsize=(15,10));
# il existe des valeurs de transaction en plusieurs centaines de millions d'euros.

# %%
# Pour y voir plus clair, Voyons ce qu'il se passe si on maximise à 10 Millions d'euros.
df_max10M=df[df['valeur_fonciere']<10000000]
df_max10M.boxplot(column='valeur_fonciere', by='type_local', ax=None, fontsize=None, rot=0, figsize=(15,10));

# %%
df_77=df[df['code_departement']=='77']
df_77.boxplot(column='valeur_fonciere', by='type_local', ax=None, fontsize=None, rot=0, figsize=(15,10));

# %%
df_max10M_77=df_77[df_77['valeur_fonciere']<10000000]
df_max1M_77=df_77[df_77['valeur_fonciere']<1000000]
df_max1M_77.hist(bins=50,figsize=(20,15));
#plt.show()

# %%
df_77_Maison=df_77[df_77['type_local']=='Maison']
df_77_Maison_Max_1M=df_77_Maison[df_77_Maison['valeur_fonciere']<1000000]
df_77_Maison_Max_1M.hist(bins=100,figsize=(20,15));

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2037944 entries, 0 to 2037943
# Data columns (total 29 columns):
# id_mutation                     object
# date_mutation_x                 datetime64[ns]
# numero_disposition              object
# nature_mutation                 object
# valeur_fonciere                 float64
# adresse_numero                  object
# adresse_suffixe                 object
# adresse_nom_voie                object
# adresse_code_voie               object
# code_postal                     object
# code_commune                    object
# nom_commune                     object
# code_departement                object
# id_parcelle                     object
# numero_volume                   object
# nombre_lots                     int64
# code_type_local                 float64
# type_local                      object
# surface_reelle_bati             float64
# nombre_pieces_principales       float64
# code_nature_culture             object
# ...

# %%
# Quels sont les transactions à valeur zero ?
df_77_Maison[df_77_Maison['valeur_fonciere']<10000]
# Out:
#          id_mutation date_mutation_x numero_disposition nature_mutation  \
# 1507529  2018-717795      2018-02-06             000001           Vente
# 1507995  2018-718069      2018-02-15             000001           Vente
# 1507996  2018-718069      2018-02-15             000001           Vente
# 1508737  2018-718512      2018-03-12             000001           Vente
# 1508738  2018-718512      2018-03-12             000001           Vente
# ...              ...             ...                ...             ...
# 1557897  2018-744049      2018-12-20             000001           Vente
# 1557898  2018-744049      2018-12-20             000001           Vente
# 1559968  2018-744976      2018-04-03             000001           Vente
# 1560526  2018-745192      2018-06-30             000001           Vente
# 1561442  2018-745546      2018-09-21             000001           Vente
#
#          valeur_fonciere adresse_numero adresse_suffixe  \
# ...

# %%
df[df['type_local']=='Maison']['surface_terrain'].value_counts(dropna=False)
# Out:
# 500.0      26034
# NaN        21003
# 1000.0      9730
# 800.0       3019
# 600.0       2576
#            ...
# 16188.0        1
# 10838.0        1
# 47433.0        1
# 47439.0        1
# 5883.0         1
# Name: surface_terrain, Length: 9339, dtype: int64

# %%
    #['lot1_surface_carrez'].value_counts()
