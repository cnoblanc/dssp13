# %%
# Select the biggest transaction
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 500)
base_path="/Users/christophenoblanc/Documents/ProjetsPython/DSSP_Projet_DVF"

df2018 = pd.read_pickle(base_path+'/data_dvf/DataFrame_2018')

# %%
# Selection que des maisons
Maisons=df2018[(df2018['type_local']=='Maison')]

# %%
# Recherche de la transaction avec le montant le plus élevé.
Maisons['valeur_fonciere'].idxmax()
idx_max=Maisons['valeur_fonciere'].idxmax()
id_mutation_max=Maisons.loc[[idx_max]]['id_mutation']
#print(id_mutation_max)
#print(id_mutation_max[idx_max])
Maisons[Maisons['id_mutation']==id_mutation_max[idx_max]]
# Out:
#          id_mutation date_mutation numero_disposition  \
# 2188044  2018-948432    2018-03-29             000001
#
#                             nature_mutation  valeur_fonciere adresse_numero  \
# 2188044  Vente en l'état futur d'achèvement      114000000.0            128
#
#         adresse_suffixe  adresse_nom_voie adresse_code_voie code_postal  \
# 2188044             NaN  AV DE STALINGRAD              8580       94800
#
#         code_commune nom_commune code_departement     id_parcelle  \
# 2188044        94076   Villejuif               94  94076000AV0324
#
#         numero_volume  nombre_lots  code_type_local type_local  \
# 2188044           NaN            0              1.0     Maison
#
#          surface_reelle_bati  nombre_pieces_principales code_nature_culture  \
# 2188044                 60.0                        3.0                   S
#
#         nature_culture code_nature_culture_speciale nature_culture_speciale  \
# ...

# %%
df2018[df2018['id_mutation']=='2018-2']
# Out:
#   id_mutation date_mutation numero_disposition nature_mutation  \
# 2      2018-2    2018-01-04             000001           Vente
# 3      2018-2    2018-01-04             000001           Vente
# 4      2018-2    2018-01-04             000001           Vente
# 5      2018-2    2018-01-04             000001           Vente
#
#    valeur_fonciere adresse_numero adresse_suffixe    adresse_nom_voie  \
# 2         239300.0              4             NaN  RUE DE LA BARMETTE
# 3         239300.0              4             NaN  RUE DE LA BARMETTE
# 4         239300.0              4             NaN  RUE DE LA BARMETTE
# 5         239300.0              4             NaN  RUE DE LA BARMETTE
#
#   adresse_code_voie code_postal code_commune       nom_commune  \
# 2              0025       01250        01095  Nivigne et Suran
# 3              0025       01250        01095  Nivigne et Suran
# 4              0025       01250        01095  Nivigne et Suran
# ...

# %%
df2018[6:9]
# Out:
#   id_mutation date_mutation numero_disposition nature_mutation  \
# 6      2018-3    2018-01-04             000001           Vente
# 7      2018-3    2018-01-04             000001           Vente
# 8      2018-3    2018-01-04             000001           Vente
#
#    valeur_fonciere adresse_numero adresse_suffixe adresse_nom_voie  \
# 6          90000.0            NaN             NaN      LE DRUILLET
# 7          90000.0           5050             NaN      LE DRUILLET
# 8          90000.0            NaN             NaN      LE DRUILLET
#
#   adresse_code_voie code_postal code_commune            nom_commune  \
# 6              B034       01380        01343  Saint-Cyr-sur-Menthon
# 7              B034       01380        01343  Saint-Cyr-sur-Menthon
# 8              B034       01380        01343  Saint-Cyr-sur-Menthon
#
#   code_departement     id_parcelle numero_volume  nombre_lots  \
# 6               01  01343000ZR0359           NaN            0
# ...

# %%
df2018[18:26]
# Out:
#    id_mutation date_mutation numero_disposition nature_mutation  \
# 18     2018-11    2018-01-08             000001           Vente
# 19     2018-11    2018-01-08             000001           Vente
# 20     2018-11    2018-01-08             000001           Vente
# 21     2018-11    2018-01-08             000001           Vente
# 22     2018-11    2018-01-08             000001           Vente
# 23     2018-11    2018-01-08             000001           Vente
# 24     2018-11    2018-01-08             000001           Vente
# 25     2018-11    2018-01-08             000001           Vente
#
#     valeur_fonciere adresse_numero adresse_suffixe adresse_nom_voie  \
# 18          47700.0            NaN             NaN          LE LAIT
# 19          47700.0            NaN             NaN          LE LAIT
# 20          47700.0            NaN             NaN          LE LAIT
# 21          47700.0            NaN             NaN          LE LAIT
# ...
